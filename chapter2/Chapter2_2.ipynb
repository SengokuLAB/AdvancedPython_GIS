# %%
# %matplotlib inline 
import numpy as np 
import pandas as pd 
import geopandas as gpd 
from shapely.geometry import Point

# %%
data = [
    [1, '東京都世田谷区'], [2, '三軒茶屋駅']
]
columns = ['id', 'addr']
df = pd.DataFrame(data=data, columns=columns)
df
# Out:
#    id     addr
# 0   1  東京都世田谷区
# 1   2    三軒茶屋駅

# %%
gdf = gpd.tools.geocode(df['addr'], provider='nominatim', user_agent="my-application")

# %%
gdf
# Out:
#                          geometry                                     address
# 0     POINT (139.65627 35.646096)                         世田谷区, 東京都, 関東地方, 日本
# 1  POINT (139.6719618 35.6437264)  三軒茶屋駅, 玉川通り, 世田谷区, 東京都, 関東地方, 154-0004, 日本

# %%
chome_gdf = gpd.read_file("./shp/h27ka13112.shp")
ax = chome_gdf.plot(
    color='white', edgecolor='black')
gdf.plot(ax=ax, color='red')

plt.show()
