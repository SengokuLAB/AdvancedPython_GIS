# %%
import folium
m = folium.Map(location=[35.643554, 139.671146], zoom_start=12)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tooltip = 'Click me!'
folium.Marker([35.643554, 139.671146], popup='<i>三軒茶屋駅</i>', tooltip=tooltip).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium.Marker([35.645554, 139.672146], popup='<i>三軒茶屋駅</i>', tooltip=tooltip).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# %matplotlib inline 
import numpy as np 
import pandas as pd 
import geopandas as gpd 
from folium.plugins import MarkerCluster
from shapely.geometry import Point

# %%
df = pd.read_csv("./draft/data/peseudo_rent_data.csv")
geometry = [Point(lonlat) for lonlat in zip(df["物件経度"], df["物件緯度"])] 
crs = {'init': 'epsg:4326'}
gdf = gpd.GeoDataFrame(df, geometry=geometry, crs=crs)

# %%
# !pwd
# Out:
# /Users/xianshiyuming/Dropbox/git/sngklab/GISBook

# %%
m = folium.Map(location=[35.643554, 139.671146], zoom_start=12)
location = np.array([df["物件緯度"], df["物件経度"]]).T
marker_cluster = MarkerCluster(location).add_to(m)
                     
#for i, row in gdf.iterrows():
#    folium.Marker(location=[row['物件緯度'],  row['物件経度']],
#        popup=row['間取別平均平米単価①'],
#        icon=folium.Icon(color='green', icon='ok-sign'),
#    ).add_to(marker_cluster)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m.save(outfile="map.html")
